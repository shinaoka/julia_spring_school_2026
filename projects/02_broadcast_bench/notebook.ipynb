# %% [markdown]
# # 02 broadcast bench\n\n`sin.(x)` を計測して、broadcastの速度感（要素/秒）を掴みます。

# %%
using Pkg\nPkg.activate(".")\nPkg.instantiate()\n

# %%
include("src/BroadcastBench.jl")\nusing .BroadcastBench\n\nBroadcastBench.sin_throughput(10^6)\n
