# %% [markdown]
# # 01 linalg bench\n\n行列積 `A*B` を計測して、FLOPs/GFLOPsの感覚を掴みます。

# %%
using Pkg\nPkg.activate(".")\nPkg.instantiate()\n

# %%
include("src/LinalgBench.jl")\nusing .LinalgBench\n\nLinalgBench.gemm_gflops(256; reps=3)\n
