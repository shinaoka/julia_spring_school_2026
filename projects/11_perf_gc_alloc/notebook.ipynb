# %% [markdown]
# # 11 perf: allocation / GC\n\nallocationが増えるとなぜ遅くなりやすいか（GCの負荷）を、まず `@allocated` と BenchmarkToolsで体感します。

# %%
using Pkg\nPkg.activate(".")\nPkg.instantiate()\n

# %%
include("src/PerfGCAlloc.jl")\nusing .PerfGCAlloc\n\nPerfGCAlloc.compare(10^6)\n
