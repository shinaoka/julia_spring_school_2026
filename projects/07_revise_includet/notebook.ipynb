# %% [markdown]
# # 07 revise + includet\n\n編集→再実行を楽にするために `Revise` と `includet` を使います。\n\n1. `includet("src/ReviseDemo.jl")` で読み込む\n2. `src/ReviseDemo.jl` を編集\n3. そのまま関数を呼ぶ（再読み込みが効く）\n

# %%
using Pkg\nPkg.activate(".")\nPkg.instantiate()\n

# %%
using Revise\nincludet("src/ReviseDemo.jl")\nusing .ReviseDemo\n\nReviseDemo.square(5)\n
