# %% [markdown]
# # 04 functions & dispatch\n\n関数定義と多重ディスパッチの最小例。

# %%
using Pkg\nPkg.activate(".")\nPkg.instantiate()\n

# %%
include("src/FunctionsDispatch.jl")\nusing .FunctionsDispatch\n\nFunctionsDispatch.g(1), FunctionsDispatch.g(1.0)\n
