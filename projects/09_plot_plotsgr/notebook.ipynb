# %% [markdown]
# # 09 plot (Plots.jl + GR)\n\nVS CodeのNotebookでプロットを出します。

# %%
using Pkg\nPkg.activate(".")\nPkg.instantiate()\n

# %%
include("src/PlotPlotsGR.jl")\nusing .PlotPlotsGR\n\np = PlotPlotsGR.demo_plot()\np\n

# %%
using Plots\nsavefig(p, "sin.png")\n"saved sin.png"\n
