# %% [markdown]
# # 10 debug basics\n\nstacktraceの読み方、`@show`/`@assert` の入口。

# %%
using Pkg\nPkg.activate(".")\nPkg.instantiate()\n

# %%
include("src/DebugBasics.jl")\nusing .DebugBasics\n\nx = rand(5)\n@show x\nDebugBasics.mean_checked(x)\n

# %%
# これはAssertionErrorを出す\nDebugBasics.mean_checked(Float64[])\n
