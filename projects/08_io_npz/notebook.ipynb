# %% [markdown]
# # 08 io npz\n\nPython連携を想定して `.npy/.npz` を扱います（NPZ.jl）。

# %%
using Pkg\nPkg.activate(".")\nPkg.instantiate()\n

# %%
include("src/IONPZ.jl")\nusing .IONPZ\n\nA = rand(3,4)\nB = IONPZ.write_read_npy("A.npy", A)\nsize(A), size(B)\n
