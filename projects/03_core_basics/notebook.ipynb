# %% [markdown]
# # 03 core basics\n\nfor/if、配列、viewとコピーなど、最小限を触ります。

# %%
using Pkg\nPkg.activate(".")\nPkg.instantiate()\n

# %%
include("src/CoreBasics.jl")\nusing .CoreBasics\n\nCoreBasics.harmonic(10)\n
